# %% [markdown]
# <a href="https://colab.research.google.com/github/beepmo/gator/blob/main/data/0807/La2_3b_2Vpp_Hgating.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from google.colab import userdata
import plotly.express as px

# %% [markdown]
# # 1. Set up project in runtime
# Create colab secrets for the following credentials for the repo to get runtime files and clone repo

# %%
# !git config --global user.email {userdata.get('email')}
# !git config --global user.name {userdata.get('name')}
# !git clone https://{userdata.get('token')}@github.com/beepmo/gator
# %pwd
# Out:
# /bin/bash: -c: line 1: syntax error near unexpected token `('
# /bin/bash: -c: line 1: `git config --global user.email {userdata.get('email')}'
# Cloning into 'gator'...
# remote: Enumerating objects: 1515, done.
# remote: Counting objects: 100% (104/104), done.
# remote: Compressing objects: 100% (86/86), done.
# remote: Total 1515 (delta 74), reused 17 (delta 17), pack-reused 1411
# Receiving objects: 100% (1515/1515), 103.13 MiB | 24.53 MiB/s, done.
# Resolving deltas: 100% (896/896), done.
# Updating files: 100% (198/198), done.
# '/content'

# %% [markdown]
# ### 24-08-06 La2/3-b Hgating
# **Only use HMIM-TFSI**
#
# Gate voltage parameters :
# - Amp : 2Vpp
# - Offset : 500 mV
# - Duty Cycle : 1%
# - Power supply: 1V
#
#  Time 1250: Start gating

# %%
# %cd "/content/gator/data/0807/"
# Out:
# /content/gator/data/0807

# %%
# prompt: delete first 8 lines from full_buffer.csv

def prep_csv(filename):

  # Read the full buffer into a list of lines
  with open(filename, 'r') as f:
    lines = f.readlines()

  # print base time
  print(lines[2])

  # Delete the first 8 lines
  lines = lines[8:]

  # Write the remaining lines back to the file
  with open(filename, 'w') as f:
    f.writelines(lines)

# %%
prep_csv('/content/gator/data/0807/defbuffer1_0806_144324.csv')
df = pd.read_csv('/content/gator/data/0807/defbuffer1_0806_144324.csv')
# Out:
# Fill Mode,1

# %%
df
# Out:
#         Reading    Unit  Range Digits  Disp Digits Math Start Group  \
# 0      0.007049  Amp DC          0.01          5.5    F           F
# 1      0.007049  Amp DC          0.01          5.5    F           F
# 2      0.007049  Amp DC          0.01          5.5    F           F
# 3      0.007049  Amp DC          0.01          5.5    F           F
# 4      0.007049  Amp DC          0.01          5.5    F           F
# ...         ...     ...           ...          ...  ...         ...
# 12361  0.007129  Amp DC          0.01          5.5    F           F
# 12362  0.007129  Amp DC          0.01          5.5    F           F
# 12363  0.007117  Amp DC          0.01          5.5    F           F
# 12364  0.007119  Amp DC          0.01          5.5    F           F
# 12365  0.007130  Amp DC          0.01          5.5    F           F
#
#       Limit1 High Limit1 Low Limit2 High Limit2 Low  ... Questionable Origin  \
# 0               F          F           F          F  ...            F   Main
# 1               F          F           F          F  ...            F   Main
# 2               F          F           F          F  ...            F   Main
# 3               F          F           F          F  ...            F   Main
# 4               F          F           F          F  ...            F   Main
# ...           ...        ...         ...        ...  ...          ...    ...
# 12361           F          F           F          F  ...            F   Main
# 12362           F          F           F          F  ...            F   Main
# 12363           F          F           F          F  ...            F   Main
# 12364           F          F           F          F  ...            F   Main
# 12365           F          F           F          F  ...            F   Main
#
#           Value   Unit.1 Digits  Output Sense Source Limit Overtemp  \
# 0      0.999959  Volt DC      1       T    2W            F        F
# 1      0.999961  Volt DC      1       T    2W            F        F
# 2      0.999961  Volt DC      1       T    2W            F        F
# 3      0.999961  Volt DC      1       T    2W            F        F
# 4      0.999961  Volt DC      1       T    2W            F        F
# ...         ...      ...    ...     ...   ...          ...      ...
# 12361  0.999960  Volt DC      1       T    2W            F        F
# 12362  0.999959  Volt DC      1       T    2W            F        F
# 12363  0.999960  Volt DC      1       T    2W            F        F
# 12364  0.999959  Volt DC      1       T    2W            F        F
# 12365  0.999960  Volt DC      1       T    2W            F        F
#
#       Relative Time
# 0          0.000000
# 1          0.069381
# 2          0.138702
# 3          0.208017
# 4          0.277346
# ...             ...
# 12361    856.959124
# 12362    857.028462
# 12363    857.097802
# 12364    857.167135
# 12365    857.236459
#
# [12366 rows x 21 columns]

# %%
# Time (s)
T = df['Relative Time']

# Current (nA)
I = df['Reading'] * 1e12

# Potential (mV)
V = df['Value'] * 1e3

# %%
plt.figure(figsize=(10, 6))

plt.plot(T, I)

plt.xlabel('Time (s)')
plt.ylabel('Current (nA)')

plt.title('Current vs. Time')

plt.grid(True)
plt.show()

# %%
df_new = df[['Relative Time', 'Value', 'Reading']]
df_new.loc[:, 'Reading'] = df_new['Reading'] * 1e12
df_new.loc[:, 'Value'] = df_new['Value'] * 100
df_new.rename(columns={'Reading': 'Current (nA)', 'Value': 'Vds (1e-2 V)'}, inplace=True)
# Out:
# <ipython-input-19-05c1968da0ac>:4: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
fig = px.scatter(df_new, x="Relative Time", y=["Current (nA)"])
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="70074ca6-0062-40e6-ae55-106abe462536" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("70074ca6-0062-40e6-ae55-106abe462536")) {                    Plotly.newPlot(                        "70074ca6-0062-40e6-ae55-106abe462536",                        [{"hovertemplate":"variable=Current (nA)\u003cbr\u003eRelative Time=%{x}\u003cbr\u003evalue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Current (nA)","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"Current (nA)","showlegend":true,"x":[0.0,0.06938066,0.13870234,0.20801674,0.2773461,0.34665108,0.41597538,0.48529428,0.55460128,0.62391612,0.69323938,0.76254318,0.83186566,0.90117414,0.97048216,1.03981648,1.1091311,1.17845862,1.24777842,1.31710848,1.38645196,1.45576612,1.52509612,1.5944192,1.66374934,1.73305896,1.80239256,1.8717165,1.94102398,2.01034288,2.07966292,2.14898804,2.21832112,2.28763834,2.356953,2.42627268,2.49558872,2.5649229,2.6342522,2.70357124,2.77289892,2.84221732,2.91153298,2.98083896,3.05015076,3.11948096,3.18880386,3.25813498,3.32746772,3.39678822,3.46610044,3.53541628,3.6047302,3.67403938,3.