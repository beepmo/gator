# %% [markdown]
# <a href="https://colab.research.google.com/github/beepmo/gator/blob/main/data/06-26/H_gating.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from google.colab import userdata
import plotly.express as px

# %% [markdown]
# # 1. Set up project in runtime
# Create colab secrets for the following credentials for the repo to get runtime files and clone repo

# %%
# !git config --global user.email {userdata.get('email')}
# !git config --global user.name {userdata.get('name')}
# !git clone https://{userdata.get('token')}@github.com/beepmo/gator
# %pwd
# Out:
# Cloning into 'gator'...
# remote: Enumerating objects: 532, done.
# remote: Counting objects: 100% (335/335), done.
# remote: Compressing objects: 100% (194/194), done.
# remote: Total 532 (delta 168), reused 265 (delta 138), pack-reused 197
# Receiving objects: 100% (532/532), 25.47 MiB | 17.95 MiB/s, done.
# Resolving deltas: 100% (244/244), done.
# '/content'

# %% [markdown]
# # Bast Time
# ###

# %%
# %cd "/content/gator/data/06-26/"
# Out:
# /content/gator/data/06-26

# %%
# prompt: delete first 8 lines from full_buffer.csv

def prep_csv(filename):

  # Read the full buffer into a list of lines
  with open(filename, 'r') as f:
    lines = f.readlines()

  # print base time
  print(lines[1])

  # Delete the first 8 lines
  lines = lines[0:]

  # Write the remaining lines back to the file
  with open(filename, 'w') as f:
    f.writelines(lines)

# %%
prep_csv('defbuffer1_0626_114024.csv')
df = pd.read_csv('defbuffer1_0626_114024.csv')
# Out:
# 1.049965612765e-05,Amp DC,.00001,5.5,F,F,F,F,F,F,Front,F,Main,0.9848843812943,Volt DC,1,T,2W,F,F,0.000000000

# %%
df
# Out:
#            Reading    Unit  Range Digits  Disp Digits Math Start Group  \
# 0    -7.783942e-09  Amp DC  1.000000e-07          5.5    F           F
# 1    -1.237782e-08  Amp DC  1.000000e-06          5.5    F           F
# 2    -7.372764e-09  Amp DC  1.000000e-07          5.5    F           F
# 3    -1.164518e-08  Amp DC  1.000000e-06          5.5    F           F
# 4    -3.604838e-09  Amp DC  1.000000e-07          5.5    F           F
# ...            ...     ...           ...          ...  ...         ...
# 1375  3.792694e-09  Amp DC  1.000000e-08          5.5    F           F
# 1376  3.771376e-09  Amp DC  1.000000e-08          5.5    F           F
# 1377  3.753917e-09  Amp DC  1.000000e-08          5.5    F           F
# 1378  3.755476e-09  Amp DC  1.000000e-08          5.5    F           F
# 1379  4.675979e-09  Amp DC  1.000000e-07          5.5    F           F
#
#      Limit1 High Limit1 Low Limit2 High Limit2 Low  ... Questionable Origin  \
# ...

# %% [markdown]
# ![WhatsApp Image 2024-07-02 at 11.44.52.jpeg](data:image/jpeg;base64,...)

# %%
# Time (s)
T = df['Relative Time']

# Current (mA)
I = df['Reading']

# Potential (mV)
V = df['Value']

# %%
cut1 = 0
cut2 = -1
plt.plot(T[cut1:cut2],I[cut1:cut2],'.')
plt.ylabel('Current (nA)')
plt.xlabel('Time (s)')
# Out:
# Text(0.5, 0, 'Time (s)')

# %%
prep_csv('defbuffer1_0626_114812.csv')
df2 = pd.read_csv('defbuffer1_0626_114812.csv')
# Out:
# -3.186319008819e-05,Amp DC,.0001,5.5,F,F,F,F,F,F,Front,F,Main,-0.9999538064003,Volt DC,1,T,2W,F,F,0.000000000

# %%
df2
# Out:
#        Reading    Unit  Range Digits  Disp Digits Math Start Group  \
# 0    -0.000032  Amp DC       0.00010          5.5    F           F
# 1    -0.000030  Amp DC       0.00010          5.5    F           F
# 2    -0.000029  Amp DC       0.00010          5.5    F           F
# 3    -0.000007  Amp DC       0.00001          5.5    F           F
# 4    -0.000007  Amp DC       0.00001          5.5    F           F
# ...        ...     ...           ...          ...  ...         ...
# 5559 -0.000035  Amp DC       0.00010          5.5    F           F
# 5560 -0.000035  Amp DC       0.00010          5.5    F           F
# 5561 -0.000035  Amp DC       0.00010          5.5    F           F
# 5562 -0.000035  Amp DC       0.00010          5.5    F           F
# 5563 -0.000035  Amp DC       0.00010          5.5    F           F
#
#      Limit1 High Limit1 Low Limit2 High Limit2 Low  ... Questionable Origin  \
# 0              F          F           F          F  ...            F   Main
# ...

# %% [markdown]
# ![WhatsApp Image 2024-07-02 at 11.45.23.jpeg](data:image/jpeg;base64,...)

# %%
# Time (s)
T = df2['Relative Time']

# Current (mA)
I = df2['Reading']

# Potential (mV)
V = df2['Value']

# %%
cut1 = 0
cut2 = -1
plt.plot(T[cut1:cut2],I[cut1:cut2],'.')
plt.ylabel('Current (nA)')
plt.xlabel('Time (s)')
# Out:
# Text(0.5, 0, 'Time (s)')

# %%
prep_csv('defbuffer1_0626_153823.csv')
df3 = pd.read_csv('defbuffer1_0626_153823.csv')
# Out:
# -2.146157839888e-06,Amp DC,.00001,5.5,F,F,F,F,F,F,Front,F,Main,0.9999914765358,Volt DC,1,T,2W,F,F,0.000000000

# %%
df3
# Out:
#       Reading    Unit  Range Digits  Disp Digits Math Start Group Limit1 High  \
# 0   -0.000002  Amp DC       0.00001          5.5    F           F           F
# 1   -0.000003  Amp DC       0.00001          5.5    F           F           F
# 2   -0.000003  Amp DC       0.00001          5.5    F           F           F
# 3   -0.000004  Amp DC       0.00001          5.5    F           F           F
# 4   -0.000004  Amp DC       0.00001          5.5    F           F           F
# ..        ...     ...           ...          ...  ...         ...         ...
# 592  0.000002  Amp DC       0.00001          5.5    F           F           F
# 593  0.000002  Amp DC       0.00001          5.5    F           F           F
# 594  0.000003  Amp DC       0.00001          5.5    F           F           F
# 595  0.000003  Amp DC       0.00001          5.5    F           F           F
# 596  0.000004  Amp DC       0.00001          5.5    F           F           F
#
# ...

# %%
# Time (s)
T = df3['Relative Time']

# Current (mA)
I = df3['Reading']

# Potential (mV)
V = df3['Value']

# %%
cut1 = 0
cut2 = -1
plt.plot(T[cut1:cut2],I[cut1:cut2],'.')
plt.ylabel('Current (nA)')
plt.xlabel('Time (s)')
# Out:
# Text(0.5, 0, 'Time (s)')

# %%
prep_csv('defbuffer1_0626_154216.csv')
df4 = pd.read_csv('defbuffer1_0626_154216.csv')
# Out:
# 0.0001010998967104,Amp DC,.001,5.5,F,F,F,F,F,F,Front,F,Main,0.9999801516533,Volt DC,1,T,2W,F,F,0.000000000

# %%
df4
# Out:
#       Reading    Unit  Range Digits  Disp Digits Math Start Group Limit1 High  \
# 0    0.000101  Amp DC        0.0010          5.5    F           F           F
# 1    0.000096  Amp DC        0.0001          5.5    F           F           F
# 2    0.000094  Amp DC        0.0001          5.5    F           F           F
# 3    0.000092  Amp DC        0.0001          5.5    F           F           F
# 4    0.000090  Amp DC        0.0001          5.5    F           F           F
# ..        ...     ...           ...          ...  ...         ...         ...
# 592  0.000067  Amp DC        0.0001          5.5    F           F           F
# 593  0.000068  Amp DC        0.0001          5.5    F           F           F
# 594  0.000069  Amp DC        0.0001          5.5    F           F           F
# 595  0.000070  Amp DC        0.0001          5.5    F           F           F
# 596  0.000071  Amp DC        0.0001          5.5    F           F           F
#
# ...

# %%
# Time (s)
T = df4['Relative Time']

# Current (mA)
I = df4['Reading']

# Potential (mV)
V = df4['Value']

# %%
cut1 = 0
cut2 = -1
plt.plot(T[cut1:cut2],I[cut1:cut2],'.')
plt.ylabel('Current (nA)')
plt.xlabel('Time (s)')
# Out:
# Text(0.5, 0, 'Time (s)')
