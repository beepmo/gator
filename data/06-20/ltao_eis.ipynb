# %% [markdown]
# <a href="https://colab.research.google.com/github/beepmo/gator/blob/main/data/06-20/ltao_eis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q impedance
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.4/48.4 kB 282.5 kB/s eta 0:00:00

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from google.colab import userdata
from impedance import preprocessing
from impedance.models.circuits import CustomCircuit

# %%
# !git config --global user.email {userdata.get('email')}
# !git config --global user.name {userdata.get('name')}
# !git clone https://{userdata.get('token')}@github.com/beepmo/gator
# %pwd
# Out:
# Cloning into 'gator'...
# remote: Enumerating objects: 589, done.
# remote: Counting objects: 100% (392/392), done.
# remote: Compressing objects: 100% (249/249), done.
# remote: Total 589 (delta 199), reused 271 (delta 140), pack-reused 197
# Receiving objects: 100% (589/589), 27.47 MiB | 8.25 MiB/s, done.
# Resolving deltas: 100% (275/275), done.
# Updating files: 100% (72/72), done.
# '/content'

# %%
# %cd gator/data/
# %cd data
# %cd 06-20
# %pwd
# %ls
# Out:
# /content/gator/data
# [Errno 2] No such file or directory: 'data'
# /content/gator/data
# /content/gator/data/06-20
# 0620_eis_05_LiTaO.z  0620_eis_LNO_02.z  defbuffer1_0620_124209.csv  LiTao3_ltoh.z
# 0620_eis_06_LiTaO.z  0620_eis_LNO_03.z  litao3_gating.ipynb         ltao_eis.ipynb
# 0620_eis_LNO_01.z    0620_eis_LNO_04.z  LiTao3_htol.z

# %% [markdown]
# # LiTaO3

# %%
freqs, Z = preprocessing.readZPlot('0620_eis_05_LiTaO.z')

plt.plot(Z.real, Z.imag, 'o')
plt.ylabel('Imaginary')
plt.xlabel('Real')
plt.title('Nyquist')
plt.show()

plt.plot(freqs, abs(Z), 'o')
plt.ylabel('|Z|')
plt.xlabel('freq')
plt.title('Bode')
plt.show()

# %%
freqs, Z = preprocessing.readZPlot('0620_eis_06_LiTaO.z')

plt.plot(Z.real, Z.imag, 'o')
plt.ylabel('Imaginary')
plt.xlabel('Real')
plt.title('Nyquist')
plt.show()

plt.plot(freqs, abs(Z), 'o')
plt.ylabel('|Z|')
plt.xlabel('freq')
plt.title('Bode')
plt.show()

# %% [markdown]
# # LiNbO3

# %%
freqs, Z = preprocessing.readZPlot('0620_eis_LNO_02.z') # low to hi

plt.plot(Z.real, Z.imag, 'o')
plt.ylabel('Imaginary')
plt.xlabel('Real')
plt.title('Nyquist')
plt.show()

plt.plot(freqs, abs(Z), 'o')
plt.ylabel('|Z|')
plt.xlabel('freq')
plt.title('Bode')
plt.show()

# %%
freqs, Z = preprocessing.readZPlot('0620_eis_LNO_03.z') # hi to lo

plt.plot(Z.real, Z.imag, 'o')
plt.ylabel('Imaginary')
plt.xlabel('Real')
plt.title('Nyquist')
plt.show()

plt.plot(freqs, abs(Z), 'o')
plt.ylabel('|Z|')
plt.xlabel('freq')
plt.title('Bode')
plt.show()

# %%
freqs, Z = preprocessing.readZPlot('0620_eis_LNO_04.z') # hi to lo

plt.plot(Z.real, Z.imag, 'o')
plt.ylabel('Imaginary')
plt.xlabel('Real')
plt.title('Nyquist')
plt.show()

plt.plot(freqs, abs(Z), 'o')
plt.ylabel('|Z|')
plt.xlabel('freq')
plt.title('Bode')
plt.show()
