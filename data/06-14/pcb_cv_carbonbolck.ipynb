# %% [markdown]
# <a href="https://colab.research.google.com/github/beepmo/gator/blob/main/data/06-14/pcb_cv_carbonbolck.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from google.colab import userdata

# %% [markdown]
# # 1. Set up project in runtime
# Create colab secrets for the following credentials for the repo to get runtime files and clone repo

# %%
# !git config --global user.email {userdata.get('email')}
# !git config --global user.name {userdata.get('name')}
# !git clone https://{userdata.get('token')}@github.com/beepmo/gator
# %pwd
# Out:
# Cloning into 'gator'...
# remote: Enumerating objects: 294, done.
# remote: Counting objects: 100% (97/97), done.
# remote: Compressing objects: 100% (91/91), done.
# remote: Total 294 (delta 51), reused 6 (delta 6), pack-reused 197
# Receiving objects: 100% (294/294), 11.64 MiB | 6.61 MiB/s, done.
# Resolving deltas: 100% (127/127), done.
# Updating files: 100% (30/30), done.
# '/content'

# %% [markdown]
# # 14-06-24 Electrolysis of Ionic liquid
# - Scan: linear dual
# - start: 0V
# - Stop: 3V
# - No. of points: 100
# - electrode: carbon block![PHOTO-2024-06-14-15-56-28.jpg](data:image/jpeg;base64,...![PHOTO-2024-06-14-16-09-27.jpg](data:image/jpeg;base64,...))
#
# # Base Time
# 06/14/2024 14:12

# %%
# %cd "/content/gator/data/06-14"
# Out:
# /content/gator/data/06-14

# %%
df = pd.read_csv('defbuffer1_0614_141756.csv')

# %%
# Time (s)
T = df['Relative Time']

# Current (mA)
I = df['Reading'] * 1e3

# Potential (mV)
V = df['Value'] * 1e3

# %%
cut1 = 0
cut2 = len(V)
plt.plot(V[cut1:cut2],I[cut1:cut2],'.')
plt.ylabel('Current (nA)')
plt.xlabel('Potential (mV)')
# Out:
# Text(0.5, 0, 'Potential (mV)')

# %%
cut1 = 0
cut2 = len(V) // 3
cut3 = len(V) * 2 // 3
plt.plot(V[cut1:cut2],I[cut1:cut2],'.')
plt.ylabel('Current (nA)')
plt.xlabel('Potential (mV)')

plt.figure()
plt.plot(V[cut2:cut3],I[cut2:cut3],'.')
plt.ylabel('Current (nA)')
plt.xlabel('Potential (mV)')


plt.figure()
plt.plot(V[cut3:],I[cut3:],'.')
plt.ylabel('Current (nA)')
plt.xlabel('Potential (mV)')
# Out:
# Text(0.5, 0, 'Potential (mV)')

# %% [markdown]
# # 14-06-24 Electrolysis of Ionic liquid
# - Scan: linear dual
# - start: 0V
# - Stop: 3V
# - No. of points: 100
# - electrode: carbon-coated PCB
#
# # Base Time
# 06/14/2024 14:37

# %%
# %cd "/content/gator/data/06-14"
# Out:
# /content/gator/data/06-14

# %% [markdown]
# ![PHOTO-2024-06-14-16-34-30.jpg](data:image/jpeg;base64,...)

# %%
df = pd.read_csv('defbuffer1_0614_152837.csv')

# %%
# Time (s)
T = df['Relative Time']

# Current (mA)
I = df['Reading'] * 1e3

# Potential (mV)
V = df['Value'] * 1e3

# %%
cut1 = 0
cut2 = len(V)
plt.plot(V[cut1:cut2],I[cut1:cut2],'.')
plt.ylabel('Current (nA)')
plt.xlabel('Potential (mV)')
# Out:
# Text(0.5, 0, 'Potential (mV)')

# %%
cut1 = 0
cut2 = len(V) // 3
cut3 = len(V) * 2 // 3
plt.plot(V[cut1:cut2],I[cut1:cut2],'.')
plt.ylabel('Current (nA)')
plt.xlabel('Potential (mV)')

plt.figure()
plt.plot(V[cut2:cut3],I[cut2:cut3],'.')
plt.ylabel('Current (nA)')
plt.xlabel('Potential (mV)')


plt.figure()
plt.plot(V[cut3:],I[cut3:],'.')
plt.ylabel('Current (nA)')
plt.xlabel('Potential (mV)')
# Out:
# Text(0.5, 0, 'Potential (mV)')
