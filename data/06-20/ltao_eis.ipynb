# %% [markdown]
# <a href="https://colab.research.google.com/github/beepmo/gator/blob/main/data/06-20/ltao_eis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from google.colab import userdata

# %%
# !pip install -q impedance
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.4/48.4 kB 631.8 kB/s eta 0:00:00

# %%
from impedance import preprocessing

# %%
# !git config --global user.email {userdata.get('email')}
# !git config --global user.name {userdata.get('name')}
# !git clone https://{userdata.get('token')}@github.com/beepmo/gator
# %pwd
# Out:
# Cloning into 'gator'...
# remote: Enumerating objects: 352, done.
# remote: Counting objects: 100% (155/155), done.
# remote: Compressing objects: 100% (143/143), done.
# remote: Total 352 (delta 78), reused 21 (delta 10), pack-reused 197
# Receiving objects: 100% (352/352), 15.80 MiB | 15.66 MiB/s, done.
# Resolving deltas: 100% (154/154), done.
# '/content'

# %%
# %cd gator/data/
# %cd data
# %cd 06-20
# %pwd
# %ls
# Out:
# /content/gator/data
# [Errno 2] No such file or directory: 'data'
# /content/gator/data
# /content/gator/data/06-20
# 0620_eis_05_LiTaO.z  0620_eis_LNO_01.z  0620_eis_LNO_03.z  ltao_eis.ipynb
# 0620_eis_06_LiTaO.z  0620_eis_LNO_02.z  0620_eis_LNO_04.z

# %% [markdown]
# # LiTaO3

# %%
freqs, Z = preprocessing.readZPlot('0620_eis_05_LiTaO.z')

plt.plot(Z.real, Z.imag, 'o')
plt.ylabel('Imaginary')
plt.xlabel('Real')
plt.title('Nyquist')
plt.show()

# %%
freqs, Z = preprocessing.readZPlot('0620_eis_06_LiTaO.z')

plt.plot(Z.real, Z.imag, 'o')
plt.ylabel('Imaginary')
plt.xlabel('Real')
plt.title('Nyquist')
plt.show()

# %% [markdown]
# # LiNbO3

# %%
freqs, Z = preprocessing.readZPlot('0620_eis_LNO_02.z')

plt.plot(Z.real, Z.imag, 'o')
plt.ylabel('Imaginary')
plt.xlabel('Real')
plt.title('Nyquist')
plt.show()

# %%
freqs, Z = preprocessing.readZPlot('0620_eis_LNO_03.z')

plt.plot(Z.real, Z.imag, 'o')
plt.ylabel('Imaginary')
plt.xlabel('Real')
plt.title('Nyquist')
plt.show()

# %%
freqs, Z = preprocessing.readZPlot('0620_eis_LNO_04.z')

plt.plot(Z.real, Z.imag, 'o')
plt.ylabel('Imaginary')
plt.xlabel('Real')
plt.title('Nyquist')
plt.show()
