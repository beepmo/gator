# %% [markdown]
# <a href="https://colab.research.google.com/github/beepmo/gator/blob/main/data/07-18/Ycutlitao3__DCmeasurement.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from google.colab import userdata
import plotly.express as px

# %% [markdown]
# # 1. Set up project in runtime
# Create colab secrets for the following credentials for the repo to get runtime files and clone repo

# %%
# !git config --global user.email {userdata.get('email')}
# !git config --global user.name {userdata.get('name')}
# !git clone https://{userdata.get('token')}@github.com/beepmo/gator
# %pwd
# Out:
# Cloning into 'gator'...
# remote: Enumerating objects: 906, done.
# remote: Counting objects: 100% (196/196), done.
# remote: Compressing objects: 100% (174/174), done.
# remote: Total 906 (delta 127), reused 31 (delta 21), pack-reused 710
# Receiving objects: 100% (906/906), 47.96 MiB | 19.01 MiB/s, done.
# Resolving deltas: 100% (496/496), done.
# Updating files: 100% (121/121), done.
# '/content'

# %% [markdown]
# ### 18-07-24 Constant voltage DC measurement on dry sample
#
# Voltage : 2V

# %%
# %cd "/content/gator/data/07-18/"
# Out:
# /content/gator/data/07-18

# %%
# prompt: delete first 8 lines from full_buffer.csv

def prep_csv(filename):

  # Read the full buffer into a list of lines
  with open(filename, 'r') as f:
    lines = f.readlines()

  # print base time
  print(lines[2])

  # Delete the first 8 lines
  lines = lines[8:]

  # Write the remaining lines back to the file
  with open(filename, 'w') as f:
    f.writelines(lines)

# %%
prep_csv('defbuffer1_0718_100501.csv')
df = pd.read_csv('defbuffer1_0718_100501.csv')
# Out:
# Fill Mode,1

# %%
df
# Out:
#             Reading    Unit  Range Digits  Disp Digits Math Start Group  \
# 0      1.717748e-13  Amp DC  1.000000e-07          5.5    F           F
# 1      5.915921e-12  Amp DC  1.000000e-07          5.5    F           F
# 2      4.671133e-12  Amp DC  1.000000e-07          5.5    F           F
# 3      4.107849e-12  Amp DC  1.000000e-07          5.5    F           F
# 4      2.807426e-12  Amp DC  1.000000e-07          5.5    F           F
# ...             ...     ...           ...          ...  ...         ...
# 10570  6.857793e-11  Amp DC  1.000000e-07          5.5    F           F
# 10571  5.963776e-11  Amp DC  1.000000e-08          5.5    F           F
# 10572  5.693683e-11  Amp DC  1.000000e-08          5.5    F           F
# 10573  5.844045e-11  Amp DC  1.000000e-08          5.5    F           F
# 10574  6.357079e-11  Amp DC  1.000000e-08          5.5    F           F
#
#       Limit1 High Limit1 Low Limit2 High Limit2 Low  ... Questionable Origin  \
# 0               F          F           F          F  ...            F   Main
# 1               F          F           F          F  ...            F   Main
# 2               F          F           F          F  ...            F   Main
# 3               F          F           F          F  ...            F   Main
# 4               F          F           F          F  ...            F   Main
# ...           ...        ...         ...        ...  ...          ...    ...
# 10570           F          F           F          F  ...            F   Main
# 10571           F          F           F          F  ...            F   Main
# 10572           F          F           F          F  ...            F   Main
# 10573           F          F           F          F  ...            F   Main
# 10574           F          F           F          F  ...            F   Main
#
#           Value   Unit.1 Digits  Output Sense Source Limit Overtemp  \
# 0      0.000002  Volt DC   0.01       F    2W            F        F
# 1      0.000002  Volt DC   0.01       F    2W            F        F
# 2      0.000002  Volt DC   0.01       F    2W            F        F
# 3      0.000003  Volt DC   0.01       F    2W            F        F
# 4      0.000002  Volt DC   0.01       F    2W            F        F
# ...         ...      ...    ...     ...   ...          ...      ...
# 10570  1.999961  Volt DC   1.00       T    2W            F        F
# 10571  1.997776  Volt DC   1.00       T    2W            F        F
# 10572  1.997822  Volt DC   1.00       T    2W            F        F
# 10573  1.997791  Volt DC   1.00       T    2W            F        F
# 10574  1.997884  Volt DC   1.00       T    2W            F        F
#
#       Relative Time
# 0          0.000000
# 1          0.535085
# 2          1.070127
# 3          1.605173
# 4          2.140185
# ...             ...
# 10570   1623.860718
# 10571   1624.102421
# 10572   1624.171768
# 10573   1624.241094
# 10574   1624.310425
#
# [10575 rows x 21 columns]

# %%
# Time (s)
T = df['Relative Time']

# Current (nA)
I = df['Reading']*1e9

# Potential (mV)
V = df['Value']

# %%
cut1 = 0
cut2 = -1
V_numeric = np.array(V, dtype=float)

#mask = V_numeric > 1
#T=T[mask]
#I=I[mask]
plt.plot(T[cut1:cut2],I[cut1:cut2],'.')
plt.ylabel('Current (nA)')
plt.xlabel('Time (s)')
# Out:
# Text(0.5, 0, 'Time (s)')

# %% [markdown]
# Big drop in current

# %%
df_new = df[['Relative Time', 'Value', 'Reading']]
df_new.loc[:, 'Reading'] = df_new['Reading'] * 1e9
df_new.loc[:, 'Value'] = df_new['Value']
df_new.rename(columns={'Reading': 'Current (nA)', 'Value': 'Vds (1e-2 V)'}, inplace=True)
# Out:
# <ipython-input-25-db179bee8aa1>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_new.rename(columns={'Reading': 'Current (nA)', 'Value': 'Vds (1e-2 V)'}, inplace=True)

# %%
# prompt: generately plotly express scatter plots of current and voltage over time from df_new

# fig = px.scatter(df_new, x="Relative Time", y=["Current (nA)", "Vds (1e-2 V)"])
fig = px.scatter(df_new, x="Relative Time", y=["Current (nA)"])
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="6ad09aaf-b805-407b-bbd8-ab1ccd49b58c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6ad09aaf-b805-407b-bbd8-ab1ccd49b58c")) {                    Plotly.newPlot(                        "6ad09aaf-b805-407b-bbd8-ab1ccd49b58c",                        [{"hovertemplate":"variable=Current (nA)\u003cbr\u003eRelative Time=%{x}\u003cbr\u003evalue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Current (nA)","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"Current (nA)","showlegend":true,"x":[0.0,0.53508546,1.07012722,1.6051732,2.1401855,2.67519004,3.21018788,3.7451726,4.28014832,4.81515828,5.3501336,5.8851169,6.42010562,6.95511528,7.49009336,8.02509668,8.56007854,9.09512516,9.6301863,10.1652202,10.70027098,11.2352909,11.77031378,12.30534262,12.84037662,13.3754189,13.9104423,14.44549682,14.98053612,15.5155532,16.05059976,16.58561128,17.12063504,17.65566058,18.19069126,18.72574446,19.26074176,19.7957509,20.3307826,20.86581226,21.40083232,21.9358394,22.47085738,23.00587884,23.5408897,24.07593228,24.61096152,25.14596612,25.6810166,26.21605928,26.7510765,27.2861138,27.8211258,28.35615338,28.89121064,29.4262375,29.9612492,30.49627784,31.03130028,31.56628866,32.1013579,32.63642098,33.17145618,33.3631437,33.7758694,34.3109646,34.84603584,35.0377649,35.45045082,35.98552224,36.52062306,37.05562828,37.59065434,38.1257338,38.66078296,39.19583168,39.73085102,40.26588752,40.80092632,41.33595806,41.871005,42.4060305,42.94106316,43.4760538,44.01102084,44.5459642,45.08092774,45.61589048,46.15085696,46.68580204,47.22074536,47.75571688,48.29067556,48.82562964,49.3605522,49.89550228,50.43048358,50.96544144,51.5004031,52.03536848,52.57029642,53.10524262,53.64020338,54.17516552,54
# 3     -1.164518e-08  Amp DC  1.000000e-06          5.5    F           F
# 4     -3.604838e-09  Amp DC  1.000000e-07          5.5    F           F
# ...             ...     ...           ...          ...  ...         ...
# 14778  2.802695e-08  Amp DC  1.000000e-07          5.5    F           F
# 14779  2.803871e-08  Amp DC  1.000000e-07          5.5    F           F
# 14780  2.807798e-08  Amp DC  1.000000e-07          5.5    F           F
# 14781  2.811762e-08  Amp DC  1.000000e-07          5.5    F           F
# 14782  2.816345e-08  Amp DC  1.000000e-07          5.5    F           F
#
#       Limit1 High Limit1 Low Limit2 High Limit2 Low  ... Questionable Origin  \
# 0               F          F           F          F  ...            F   Main
# 1               F          F           F          F  ...            F   Main
# 2               F          F           F          F  ...            F   Main
# 3               F          F           F          F  ...            F   Main
# 4               F          F           F          F  ...            F   Main
# ...           ...        ...         ...        ...  ...          ...    ...
# 14778           F          F           F          F  ...            F   Main
# 14779           F          F           F          F  ...            F   Main
# 14780           F          F           F          F  ...            F   Main
# 14781           F          F           F          F  ...            F   Main
# 14782           F          F           F          F  ...            F   Main
#
#                                                    Value   Unit.1  \
# 0      99099995300309345000000000000000000000.0000000...  Volt DC
# 1                                        0.0000026747075  Volt DC
# 2      99099995300309345000000000000000000000.0000000...  Volt DC
# 3                                        0.0000025473710  Volt DC
# 4      99099995300309345000000000000000000000.0000000...  Volt DC
# ...                                                  ...      ...
# 14778                                    0.9999758005142  Volt DC
# 14779                                    0.9999757409096  Volt DC
# 14780                                    0.9999727010727  Volt DC
# 14781                                    0.9999740719795  Volt DC
# 14782                                    0.9999739527702  Volt DC
#
#              Digits  Output Sense Source Limit Overtemp Relative Time
# 0      1.000000e+13       F    2W            F        F      0.000000
# 1      1.000000e-02       F    2W            F        F      0.372232
# 2      1.000000e+13       F    2W            F        F      1.217015
# 3      1.000000e-02       F    2W            F        F      1.588838
# 4      1.000000e+13       F    2W            F        F      2.314445
# ...             ...     ...   ...          ...      ...           ...
# 14778  1.000000e+00       T    2W            F        F   1477.580958
# 14779  1.000000e+00       T    2W            F        F   1477.650308
# 14780  1.000000e+00       T    2W            F        F   1477.719666
# 14781  1.000000e+00       T    2W            F        F   1477.789006
# 14782  1.000000e+00       T    2W            F        F   1477.858360
#
# [14783 rows x 21 columns]

# %%
# Time (s)
T = df2['Relative Time']

# Current (mA)
I = df2['Reading']

# Potential (V)
V = df2['Value']

# %%
cut1 = 0
cut2 = -1
plt.plot(T[cut1:cut2],I[cut1:cut2],'.')
plt.ylabel('Current (nA)')
plt.xlabel('Time (s)')
# Out:
# Text(0.5, 0, 'Time (s)')

# %%
cut1 = 0
cut2 = -1
V_numeric = np.array(V, dtype=float)

mask = V_numeric < 1
T=T[mask]
V=V_numeric[mask]
plt.plot(T[cut1:cut2],V[cut1:cut2],'.')
plt.ylabel('Voltage (V)')
plt.xlabel('Time (s)')
# Out:
# Text(0.5, 0, 'Time (s)')

# %% [markdown]
# ### Measuring the current between gate and drain

# %%
prep_csv('defbuffer1_0625_101051.csv')
df3 = pd.read_csv('defbuffer1_0625_101051.csv')
# Out:
# Fill Mode,1

# %%
df3
# Out:
#           Reading    Unit  Range Digits  Disp Digits Math Start Group  \
# 0   -1.886904e-10  Amp DC  1.000000e-07          5.5    F           F
# 1    5.975142e-10  Amp DC  1.000000e-06          5.5    F           F
# 2    4.967401e-10  Amp DC  1.000000e-07          5.5    F           F
# 3    5.010095e-10  Amp DC  1.000000e-07          5.5    F           F
# 4   -7.989378e-10  Amp DC  1.000000e-07          5.5    F           F
# ..            ...     ...           ...          ...  ...         ...
# 308 -1.861517e-10  Amp DC  1.000000e-07          5.5    F           F
# 309 -1.609942e-10  Amp DC  1.000000e-07          5.5    F           F
# 310 -1.686708e-10  Amp DC  1.000000e-07          5.5    F           F
# 311 -1.804916e-10  Amp DC  1.000000e-07          5.5    F           F
# 312 -1.476677e-10  Amp DC  1.000000e-06          5.5    F           F
#
#     Limit1 High Limit1 Low Limit2 High Limit2 Low  ... Questionable Origin  \
# 0             F          F           F          F  ...            F   Main
# 1             F          F           F          F  ...            F   Main
# 2             F          F           F          F  ...            F   Main
# 3             F          F           F          F  ...            F   Main
# 4             F          F           F          F  ...            F   Main
# ..          ...        ...         ...        ...  ...          ...    ...
# 308           F          F           F          F  ...            F   Main
# 309           F          F           F          F  ...            F   Main
# 310           F          F           F          F  ...            F   Main
# 311           F          F           F          F  ...            F   Main
# 312           F          F           F          F  ...            F   Main
#
#         Value   Unit.1 Digits  Output Sense Source Limit Overtemp  \
# 0   -0.000291  Volt DC      1       F    2W            F        F
# 1    0.000012  Volt DC      1       F    2W            F        F
# 2   -0.005586  Volt DC      1       F    2W            F        F
# 3   -0.005157  Volt DC      1       F    2W            F        F
# 4    0.002245  Volt DC      1       F    2W            F        F
# ..        ...      ...    ...     ...   ...          ...      ...
# 308 -0.000797  Volt DC      1       F    2W            F        F
# 309 -0.001128  Volt DC      1       F    2W            F        F
# 310 -0.001103  Volt DC      1       F    2W            F        F
# 311 -0.001067  Volt DC      1       F    2W            F        F
# 312  0.000013  Volt DC      1       F    2W            F        F
#
#     Relative Time
# 0        0.000000
# 1        0.548905
# 2        1.338817
# 3        2.060586
# 4        2.782350
# ..            ...
# 308    214.845031
# 309    215.566782
# 310    216.288552
# 311    217.010310
# 312    217.559217
#
# [313 rows x 21 columns]

# %%
# Time (s)
T = df3['Relative Time']

# Current (mA)
I = df3['Reading']

# Potential (mV)
V = df3['Value']

# %%
cut1 = 0
cut2 = -1
plt.plot(T[cut1:cut2],I[cut1:cut2],'.')
plt.ylabel('Current (nA)')
plt.xlabel('Time (s)')
# Out:
# Text(0.5, 0, 'Time (s)')

# %% [markdown]
# Mystery : when the gating voltage is applied (75%), the current measured between gate and drain is negative
# This means the Li+ go out of our crystal when we're applying a positive gating voltage, which is not what's supposed to happen

# %%
cut1 = 0
cut2 = -1
V_numeric = np.array(V, dtype=float)

mask = V_numeric < 1
T=T[mask]
V=V_numeric[mask]
plt.plot(T[cut1:cut2],V[cut1:cut2],'.')
plt.ylabel('Voltage (V)')
plt.xlabel('Time (s)')
# Out:
# Text(0.5, 0, 'Time (s)')

# %%
prep_csv('defbuffer1_0625_130822.csv')
df4 = pd.read_csv('defbuffer1_0625_130822.csv')
# Out:
# Fill Mode,1

# %%
df4
# Out:
#             Reading    Unit  Range Digits  Disp Digits Math Start Group  \
# 0      3.414072e-08  Amp DC  1.000000e-07          5.5    F           F
# 1      3.424623e-08  Amp DC  1.000000e-07          5.5    F           F
# 2      3.433125e-08  Amp DC  1.000000e-07          5.5    F           F
# 3      3.444436e-08  Amp DC  1.000000e-07          5.5    F           F
# 4      3.457074e-08  Amp DC  1.000000e-07          5.5    F           F
# ...             ...     ...           ...          ...  ...         ...
# 99995  3.342292e-08  Amp DC  1.000000e-07          5.5    F           F
# 99996  3.357656e-08  Amp DC  1.000000e-07          5.5    F           F
# 99997  3.370239e-08  Amp DC  1.000000e-07          5.5    F           F
# 99998  3.385235e-08  Amp DC  1.000000e-07          5.5    F           F
# 99999  3.397075e-08  Amp DC  1.000000e-07          5.5    F           F
#
#       Limit1 High Limit1 Low Limit2 High Limit2 Low  ... Questionable Origin  \
# 0               F          F           F          F  ...            F   Main
# 1               F          F           F          F  ...            F   Main
# 2               F          F           F          F  ...            F   Main
# 3               F          F           F          F  ...            F   Main
# 4               F          F           F          F  ...            F   Main
# ...           ...        ...         ...        ...  ...          ...    ...
# 99995           F          F           F          F  ...            F   Main
# 99996           F          F           F          F  ...            F   Main
# 99997           F          F           F          F  ...            F   Main
# 99998           F          F           F          F  ...            F   Main
# 99999           F          F           F          F  ...            F   Main
#
#           Value   Unit.1 Digits  Output Sense Source Limit Overtemp  \
# 0      0.999968  Volt DC      1       T    2W            F        F
# 1      0.999967  Volt DC      1       T    2W            F        F
# 2      0.999970  Volt DC      1       T    2W            F        F
# 3      0.999970  Volt DC      1       T    2W            F        F
# 4      0.999970  Volt DC      1       T    2W            F        F
# ...         ...      ...    ...     ...   ...          ...      ...
# 99995  0.999967  Volt DC      1       T    2W            F        F
# 99996  0.999968  Volt DC      1       T    2W            F        F
# 99997  0.999971  Volt DC      1       T    2W            F        F
# 99998  0.999970  Volt DC      1       T    2W            F        F
# 99999  0.999969  Volt DC      1       T    2W            F        F
#
#       Relative Time
# 0       6938.283304
# 1       6938.352650
# 2       6938.422002
# 3       6938.491332
# 4       6938.560672
# ...             ...
# 99995   6937.936537
# 99996   6938.005888
# 99997   6938.075219
# 99998   6938.144549
# 99999   6938.213889
#
# [100000 rows x 21 columns]

# %%
# Time (s)
T = df4['Relative Time']

# Current (mA)
I = df4['Reading']

# Potential (mV)
V = df4['Value']

# %%
cut1 = 0
cut2 = -1
plt.plot(T[cut1:cut2],I[cut1:cut2],'.')
plt.ylabel('Current (nA)')
plt.xlabel('Time (s)')
# Out:
# Text(0.5, 0, 'Time (s)')

# %% [markdown]
# # EIS on gated sample

# %%
# !pip install impedance -q

# %%
from impedance import preprocessing
from impedance.models.circuits import CustomCircuit

# %%
# %ls

# %%
freqs, Z = preprocessing.readZPlot('LiTao3_htol.z')
freqs, Z = np.delete(freqs, 32), np.delete(Z, 32) # remove 1 noise point (argmin(Z.imag))


plt.plot(Z.real, -Z.imag, 'o')
plt.ylabel('Imaginary')
plt.xlabel('Real')
plt.title('Nyquist')
plt.show()

plt.plot(freqs, -Z.imag, 'o')
plt.ylabel('Im(Z)')
plt.xlabel('freq')
plt.title('Bode')
plt.show()

# %%
freqs, Z = preprocessing.readZPlot('LiTao3_ltoh.z')
freqs, Z = np.delete(freqs, 28), np.delete(Z, 28) # remove 1 noise point (argmin(Z.imag))


plt.plot(Z.real, -Z.imag, 'o')
plt.ylabel('Imaginary')
plt.xlabel('Real')
plt.title('Nyquist')
plt.show()

plt.plot(freqs, -Z.imag, 'o')
plt.ylabel('Im(Z)')
plt.xlabel('freq')
plt.title('Bode')
plt.show()

# %%
circuit = 'p(R0,CPE0)'
init = [1e6,1e-2,1]

circuit = CustomCircuit(circuit, initial_guess=init)

# %%
circuit.fit(freqs, Z)

# %%
Z_fit = circuit.predict(freqs)

plt.plot(Z_fit.real, -Z_fit.imag, 'o')
plt.plot(Z.real, -Z.imag, 'o')
plt.ylabel('Imaginary')
plt.xlabel('Real')
plt.title('Nyquist')
plt.show()

# %%
print(circuit)
